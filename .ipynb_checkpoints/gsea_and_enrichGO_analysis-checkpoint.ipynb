# %%
# %matplotlib inline
from os import listdir
from os.path import isfile, join
import numpy as np
from glob import glob
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import matplotlib
import statsmodels.stats.multitest as smt
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
from matplotlib.colors import DivergingNorm

# %%
## GSEA from clusterProfiler
dir_path = '/Users/osipova/Documents/LabDocs/Brood_parasites_analysis/'

db = 'vidMac'
# db = 'vidCha'
# db = 'indInd'

file_name = 'MK_test_{}_ncbi/gse.tsv'.format(db)
file_data = glob(dir_path + file_name)[0]
df = pd.read_csv(file_data, sep='\t')

df['GOfull'] = df['Description'] + '  ' + df['ID']
df['logpval'] = - np.log10(df['pvalue'])
dos = [1 if x > 0 else -1 for x in df['NES']]
df['dos'] = dos
df['sign_logP'] = df['logpval'] * dos
df.sort_values(by=['sign_logP'], inplace=True, ascending=False)

df.head()
# Out:
#            ID                            Description GeneRatio    BgRatio  \
# 0  GO:0009798                     axis specification      4/73   76/11829
# 1  GO:0034113         heterotypic cell-cell adhesion      3/73   40/11829
# 2  GO:0006959                humoral immune response      4/73   89/11829
# 3  GO:0044782                    cilium organization      7/73  305/11829
# 4  GO:0033044  regulation of chromosome organization      5/73  166/11829
#
#      pvalue  p.adjust    qvalue                                   geneID  \
# 0  0.001225  0.658192  0.658192                   NOTCH2/MNS1/TASOR/GPC3
# 1  0.001891  0.658192  0.658192                             CD2/FGA/WNK1
# 2  0.002195  0.658192  0.658192                     FGA/NOTCH2/CFH/PDCD1
# 3  0.002689  0.658192  0.658192  DZIP1/PCM1/POC1B/BBS10/CDC14A/MNS1/ODF2
# 4  0.003569  0.658192  0.658192            NDC80/LIG4/DLGAP5/TASOR/RTEL1
#
#    Count                                             GOfull   logpval
# 0      4                     axis specification  GO:0009798  2.911968
# 1      3         heterotypic cell-cell adhesion  GO:0034113  2.723256
# 2      4                humoral immune response  GO:0006959  2.658645
# 3      7                    cilium organization  GO:0044782  2.570483
# 4      5  regulation of chromosome organization  GO:0033044  2.447444

# %%
## Plot p-value DoS > 0 and DoS < 0
sns.set_palette(['#2b83ba', '#d7191c'])

fig, axes = plt.subplots(figsize=(7, 5))
# fig, axes = plt.subplots(figsize=(9, 4))
# fig, axes = plt.subplots(figsize=(3, 1.2))

sns.barplot(data=df, x='sign_logP', y='GOfull', hue='dos', dodge=False)
axes.set(xlabel='dos * logP-value', ylabel='')

fig.tight_layout()  
sns.despine(fig=None, ax=None, left=False, bottom=False, offset=None, trim=False)
axes.legend([], [], frameon=False)

pdf_name = 'MK_test_{}_ncbi/gsea_top_terms.result.pdf'.format(db)
# fig.savefig(pdf_name, bbox_inches='tight')

# %%
## GO Enrichment from clusterProfiler
dir_path = '/Users/osipova/Documents/LabDocs/Brood_parasites_analysis/'

db = 'vidMac'
# db = 'vidCha'
# db = 'indInd'

file_name = 'MK_test_{}_ncbi/pos.enrichGO.tsv'.format(db)
file_data = glob(dir_path + file_name)[0]
df = pd.read_csv(file_data, sep='\t')

df['GOfull'] = df['Description'] + '  ' + df['ID']
df['logpval'] = np.log10(df['pvalue'])
df['ngenes'], df['nset'] = df['GeneRatio'].str.split('/').str
df['ratio'] = (pd.to_numeric(df['ngenes']) / pd.to_numeric(df['nset']) * 1000).astype(int)
df.set_index('GOfull', inplace=True)
df.head()
# Out:
# /Users/osipova/local/Homebrew/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#                                                            ID  \
# GOfull
# axis specification  GO:0009798                     GO:0009798
# heterotypic cell-cell adhesion  GO:0034113         GO:0034113
# humoral immune response  GO:0006959                GO:0006959
# cilium organization  GO:0044782                    GO:0044782
# regulation of chromosome organization  GO:0033044  GO:0033044
#
#                                                                              Description  \
# GOfull
# axis specification  GO:0009798                                        axis specification
# heterotypic cell-cell adhesion  GO:0034113                heterotypic cell-cell adhesion
# humoral immune response  GO:0006959                              humoral immune response
# cilium organization  GO:0044782                                      cilium organization
# regulation of chromosome organization  GO:0033044  regulation of chromosome organization
#
#                                                   GeneRatio    BgRatio  \
# GOfull
# axis specification  GO:0009798                         4/73   76/11829
# heterotypic cell-cell adhesion  GO:0034113             3/73   40/11829
# humoral immune response  GO:0006959                    4/73   89/11829
# cilium organization  GO:0044782                        7/73  305/11829
# regulation of chromosome organization  GO:0033044      5/73  166/11829
#
#                                                      pvalue  p.adjust  \
# GOfull
# axis specification  GO:0009798                     0.001225  0.658192
# heterotypic cell-cell adhesion  GO:0034113         0.001891  0.658192
# humoral immune response  GO:0006959                0.002195  0.658192
# cilium organization  GO:0044782                    0.002689  0.658192
# regulation of chromosome organization  GO:0033044  0.003569  0.658192
#
#                                                      qvalue  \
# GOfull
# axis specification  GO:0009798                     0.658192
# heterotypic cell-cell adhesion  GO:0034113         0.658192
# humoral immune response  GO:0006959                0.658192
# cilium organization  GO:0044782                    0.658192
# regulation of chromosome organization  GO:0033044  0.658192
#
#                                                                                     geneID  \
# GOfull
# axis specification  GO:0009798                                      NOTCH2/MNS1/TASOR/GPC3
# heterotypic cell-cell adhesion  GO:0034113                                    CD2/FGA/WNK1
# humoral immune response  GO:0006959                                   FGA/NOTCH2/CFH/PDCD1
# cilium organization  GO:0044782                    DZIP1/PCM1/POC1B/BBS10/CDC14A/MNS1/ODF2
# regulation of chromosome organization  GO:0033044            NDC80/LIG4/DLGAP5/TASOR/RTEL1
#
#                                                    Count   logpval ngenes  \
# GOfull
# axis specification  GO:0009798                         4 -2.911968      4
# heterotypic cell-cell adhesion  GO:0034113             3 -2.723256      3
# humoral immune response  GO:0006959                    4 -2.658645      4
# cilium organization  GO:0044782                        7 -2.570483      7
# regulation of chromosome organization  GO:0033044      5 -2.447444      5
#
#                                                   nset  ratio
# GOfull
# axis specification  GO:0009798                      73     54
# heterotypic cell-cell adhesion  GO:0034113          73     41
# humoral immune response  GO:0006959                 73     54
# cilium organization  GO:0044782                     73     95
# regulation of chromosome organization  GO:0033044   73     68

# %%
## Plot log p-value 

df_pval = df[['logpval']]

cmap = sns.diverging_palette(250, 70, 123, 35, as_cmap=True)
divnorm = DivergingNorm(np.log10(0.051))
# cmap_pval = sns.diverging_palette(10, 240, as_cmap=True)
# cmap_pval = sns.diverging_palette(10, 240, as_cmap=True)
cmap_pval = sns.diverging_palette(-70, 250, 123, 35, as_cmap=True)
divnorm_pval = DivergingNorm(vmin=-5, vmax=-1, vcenter=np.log10(0.051))

fig, axes = plt.subplots(figsize=(2.2, 7))
sns.heatmap(data=df_pval, cmap=cmap_pval, norm=divnorm_pval)
# axes.set_xticklabels(df_pval['GO'])
axes.set_ylabel('')

fig.tight_layout()

       
# pdf_name = 'MK_test_{}_ncbi/gsea_top_terms.result.pdf'.format(db)
# fig.savefig(pdf_name, bbox_inches='tight')
# Out:
# /Users/osipova/local/Homebrew/lib/python3.7/site-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The DivergingNorm class was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use TwoSlopeNorm instead.
#
# /Users/osipova/local/Homebrew/lib/python3.7/site-packages/ipykernel_launcher.py:10: MatplotlibDeprecationWarning:
# The DivergingNorm class was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use TwoSlopeNorm instead.
#   # Remove the CWD from sys.path while we load stuff.
# /Users/osipova/local/Homebrew/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %%
np.log10(0.051)
# Out:
# -1.2924298239020637
